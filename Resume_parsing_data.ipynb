# %% [markdown]
# <a href="https://colab.research.google.com/github/kazirafi71/Thesis/blob/master/Resume_parsing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install python-docx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install docx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install pyresparser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install spacy==2.3.7
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached en_core_web_sm-2.3.1-py3-none-any.whl
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
# !python -m nltk.downloader words
# Out:
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
import nltk
nltk.download('stopwords')
from pyresparser import ResumeParser

import os
from docx import Document
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
##file format should be in .txt , .docx or .pdf only
# filed=input()
filed="/content/drive/MyDrive/CV Sorting Project/Resumes/ResumeOfRafi.pdf"

# %%
filed
# Out:
# '/content/drive/MyDrive/CV Sorting Project/Resumes/ResumeOfRafi.pdf'

# %%
data = ResumeParser(filed).get_extracted_data()
# Out:
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
try:
    doc = Document()
    
    with open(filed, 'r') as file:
        doc.add_paragraph(file.read())
    doc.save("text.docx")
    data = ResumeParser('text.docx').get_extracted_data()
    print("skilss",data['skills'])
except:
    data = ResumeParser(filed).get_extracted_data()
    print("Candidate skills",data['skills'])
    print("Email",data['email'])
    print("Name",data['name'])
    print("total_experience",data['total_experience'])
    print("company_names",data['company_names'])
    print("degree",data['degree'])
    print("designation",data['designation'])
# Out:
# Candidate skills ['Engineering', 'Python', 'Css', 'Email', 'Communication', 'Mobile', 'C++', 'Django', 'C', 'Js', 'Design', 'Rest', 'Mysql', 'Grab', 'Programming', 'Github', 'Javascript', 'Postgresql', 'Java', 'Requests', 'Api', 'Website', 'Database']
# Email kazimusaddirafi@gmail.com
# Name Kazi Musaddi Rafi
# total_experience 0.83
# company_names None
# degree ['B.Sc. in Information and Communication Engineering']
# designation ['Software Engineer']

# %%
import pandas as pd

# %%
print(type (data))
# Out:
# <class 'dict'>

# %%
df = pd.DataFrame(data['skills']) 
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Another approach

# %%
pip install resume-parser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install docx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from resume_parser import resumeparse # Library 1
from pyresparser import ResumeParser #Library 2
import os
import spacy
spacy.load('en_core_web_sm')
# Out:
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
test="Skills Programming Languages Python pandas numpy scipy scikit learn matplotlib Sql Java JavaScript JQuery Machine learning Regression SVM Na  ve Bayes KNN Random Forest Decision Trees Boosting techniques Cluster Analysis Word Embedding Sentiment Analysis Natural Language processing Dimensionality reduction Topic Modelling LDA NMF PCA Neural Nets Database Visualizations Mysql SqlServer Cassandra Hbase ElasticSearch D3 js DC js Plotly kibana matplotlib ggplot Tableau Others Regular Expression HTML CSS Angular 6 Logstash Kafka Python Flask Git Docker computer vision Open CV and understanding of Deep learning Education Details Data Science Assurance Associate Data Science Assurance Associate Ernst Young LLP Skill Details JAVASCRIPT Exprience 24 months jQuery Exprience 24 months Python Exprience 24 monthsCompany Details company Ernst Young LLP description Fraud Investigations and Dispute Services Assurance TECHNOLOGY ASSISTED REVIEW TAR Technology Assisted Review assists in a elerating the review process and run analytics and generate reports Core member of a team helped in developing automated review platform tool from scratch for assisting E discovery domain this tool implements predictive coding and topic modelling by automating reviews resulting in reduced labor costs and time spent during the lawyers review Understand the end to end flow of the solution doing research and development for classification models predictive analysis and mining of the information present in text data Worked on analyzing the outputs and precision monitoring for the entire tool TAR assists in predictive coding topic modelling from the evidence by following EY standards Developed the classifier models in order to identify red flags and fraud related issues Tools Technologies Python scikit learn tfidf word2vec doc2vec cosine similarity Na  ve Bayes LDA NMF for topic modelling Vader and text blob for sentiment analysis Matplot lib Tableau dashboard for reporting MULTIPLE DATA SCIENCE AND ANALYTIC PROJECTS USA CLIENTS TEXT ANALYTICS MOTOR VEHICLE CUSTOMER REVIEW DATA Received customer feedback survey data for past one year Performed sentiment Positive Negative Neutral and time series analysis on customer comments across all 4 categories Created heat map of terms by survey category based on frequency of words Extracted Positive and Negative words across all the Survey categories and plotted Word cloud Created customized tableau dashboards for effective reporting and visualizations CHATBOT Developed a user friendly chatbot for one of our Products which handle simple questions about hours of operation reservation options and so on This chat bot serves entire product related questions Giving overview of tool via QA platform and also give recommendation responses so that user question to build chain of relevant answer This too has intelligence to build the pipeline of questions as per user requirement and asks the relevant recommended questions Tools Technologies Python Natural language processing NLTK spacy topic modelling Sentiment analysis Word Embedding scikit learn JavaScript JQuery SqlServer INFORMATION GOVERNANCE Organizations to make informed decisions about all of the information they store The integrated Information Governance portfolio synthesizes intelligence across unstructured data sources and facilitates action to ensure organizations are best positioned to counter information risk Scan data from multiple sources of formats and parse different file formats extract Meta data information push results for indexing elastic search and created customized interactive dashboards using kibana Preforming ROT Analysis on the data which give information of data which helps identify content that is either Redundant Outdated or Trivial Preforming full text search analysis on elastic search with predefined methods which can tag as PII personally identifiable information social security numbers addresses names etc which frequently targeted during cyber attacks Tools Technologies Python Flask Elastic Search Kibana FRAUD ANALYTIC PLATFORM Fraud Analytics and investigative platform to review all red flag cases     FAP is a Fraud Analytics and investigative platform with inbuilt case manager and suite of Analytics for various ERP systems It can be used by clients to interrogate their A ounting systems for identifying the anomalies which can be indicators of fraud by running advanced analytics Tools Technologies HTML JavaScript SqlServer JQuery CSS Bootstrap Node js D3 js DC js"

# %%
# Import docx NOT python-docx
import docx
from docx.shared import Pt

# Create an instance of a word document
doc = docx.Document()

doc.add_paragraph(test)

# Now save the document to a location
doc.save('drive/My Drive/DocFiles/gfg.docx')

# %%
dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/ACCOUNTANT')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/ACCOUNTANT'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/ACCOUNTANT/15906625.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/ACCOUNTANT/30361788.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/ACCOUNTANT/21031285.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/ACCOUNTANT/25749150.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/ACCOUNTANT/12338274.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/ACCOUNTANT/33527446.pdf
# ...

# %%
print(len(res_list))
# Out:
# 118

# %%
import pandas as pd
df1= pd.DataFrame(res_list)
df1['Label'] = "ACCOUNTANT"
df_label=df1['Label']
df_skills=df1['skills']
df_experience=df1['experience']

dataset1 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset1
# Out:
#           Label                                             skills  \
# 0    ACCOUNTANT  [Partnership, Compliance, Protocols, Invoices,...
# 1    ACCOUNTANT  [Process, Certification, Vendors, Tax, Analysi...
# 2    ACCOUNTANT  [Contracts, Inventory, Compliance, Peoplesoft,...
# 3    ACCOUNTANT  [Compliance, Invoices, Analytical, Regulations...
# 4    ACCOUNTANT  [Illustrator, Contracts, Inventory, Invoices, ...
# ..          ...                                                ...
# 113  ACCOUNTANT  [Transactions, Communication, Mobile, Workflow...
# 114  ACCOUNTANT  [Cash flow, Compliance, Invoices, Analytical, ...
# 115  ACCOUNTANT  [Cash flow, Inventory, Invoices, Audit, Financ...
# 116  ACCOUNTANT  [Contracts, Administration, Real estate, Invoi...
# 117  ACCOUNTANT  [Compliance, Invoices, Process improvements, I...
#
#                                             experience
# 0    [Services, Financial statements, Bank reconcil...
# ...

# %%
# ADVOCATE


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/ADVOCATE')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/ADVOCATE'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/ADVOCATE/14445309.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/ADVOCATE/35474904.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/ADVOCATE/37348041.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/ADVOCATE/89508407.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/ADVOCATE/25873425.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/ADVOCATE/31040875.pdf
# ...

# %%
import pandas as pd
df2= pd.DataFrame(res_list)
df2['Label'] = "ADVOCATE"
df_label=df2['Label']
df_skills=df2['skills']
df_experience=df2['experience']
dataset2 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset2
# Out:
#         Label                                             skills  \
# 0    ADVOCATE  [Public policy, Partnership, German, Training,...
# 1    ADVOCATE  [Partnership, Administration, Training, Money,...
# 2    ADVOCATE  [Administration, Training, Technical, Coaching...
# 3    ADVOCATE  [Strategy, Safety, Math, Travel, Communication...
# 4    ADVOCATE  [Training, Windows, Regulations, Chemicals, Ps...
# ..        ...                                                ...
# 113  ADVOCATE  [Strategy, Correspondence, Policies, Training,...
# 114  ADVOCATE  [Marketing plans, Contracts, Inventory, Traini...
# 115  ADVOCATE  [International, Excel, Presentations, Complian...
# 116  ADVOCATE  [Swot analysis, Training, Compliance, Program ...
# 117  ADVOCATE  [Training, Coaching, Phone calls, Powerpoint, ...
#
#                                             experience
# 0    [Advocate , 01/2011 to 01/2013 Company Name ï¼...
# 1    [Handle client email/phone call interactions o...
# ...

# %%
# AGRICULTURE


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/AGRICULTURE')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/AGRICULTURE'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/AGRICULTURE/54246169.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/AGRICULTURE/28165687.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/AGRICULTURE/37292350.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/AGRICULTURE/21134923.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/AGRICULTURE/21868149.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/AGRICULTURE/84512719.pdf
# ...

# %%
import pandas as pd
df3= pd.DataFrame(res_list)
df3['Label'] = "AGRICULTURE"
df_label=df3['Label']
df_skills=df3['skills']
df_experience=df3['experience']
dataset3 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset3
# Out:
#           Label                                             skills  \
# 0   AGRICULTURE  [Training, Technical, Communication, Safety, G...
# 1   AGRICULTURE  [Inventory, Training, Invoices, Analytical, Pu...
# 2   AGRICULTURE  [Cash flow, Training, Engagement, Technical, H...
# 3   AGRICULTURE  [Illustrator, Compliance, Peoplesoft, Regulati...
# 4   AGRICULTURE  [Administration, Training, Compliance, Invento...
# ..          ...                                                ...
# 58  AGRICULTURE  [Iso, Administration, Training, Protocols, Reg...
# 59  AGRICULTURE  [Administration, Training, Analytical, Communi...
# 60  AGRICULTURE  [Administration, Training, Compliance, Negotia...
# 61  AGRICULTURE  [Twitter, Inventory, Training, Chemicals, Mone...
# 62  AGRICULTURE  [Gis, Training, Technical, Communication, Spor...
#
#                                            experience
# 0   [Jan 2016 to Jan 2016, work as Language office...
# ...

# %%
# APPAREL


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/APPAREL')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/APPAREL'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/APPAREL/24533931.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/APPAREL/21807211.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/APPAREL/27694040.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/APPAREL/71767359.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/APPAREL/13386301.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/APPAREL/15535408.pdf
# ...

# %%
import pandas as pd
df4= pd.DataFrame(res_list)
df4['Label'] = "APPAREL"
df_label=df4['Label']
df_skills=df4['skills']
df_experience=df4['experience']
dataset4 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset4
# Out:
#       Label                                             skills  \
# 0   APPAREL  [Administration, Training, Sales, Recruiting, ...
# 1   APPAREL  [Contracts, Inventory, Compliance, Training, S...
# 2   APPAREL  [Fabric, Inventory, Compliance, Invoices, Admi...
# 3   APPAREL  [Illustrator, Partnership, Technical, Teaching...
# 4   APPAREL  [Partnership, Inventory, Training, Brand, Coac...
# ..      ...                                                ...
# 92  APPAREL  [Microsoft office suite, Administration, Inven...
# 93  APPAREL  [Marketing plans, Brand, Alliances, Partnershi...
# 94  APPAREL  [Excel, Training, Certification, Customer serv...
# 95  APPAREL  [Real estate, Compliance, Windows, Regulations...
# 96  APPAREL  [Partnership, Contracts, Training, Compliance,...
#
#                                            experience
# 0   [Apparel Associate Aug 2017 to Current, Compan...
# 1   [10/2017 to 12/2017, Apparel Sales Associate/C...
# ...

# %%
# ARTS


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/ARTS')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/ARTS'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/ARTS/31273413.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/ARTS/12386670.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/ARTS/93576192.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/ARTS/15306049.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/ARTS/31114531.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/ARTS/21060367.pdf
# ...

# %%
import pandas as pd
df5= pd.DataFrame(res_list)
df5['Label'] = "ARTS"
df_label=df5['Label']
df_skills=df5['skills']
df_experience=df5['experience']
dataset5 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset5
# Out:
#     Label                                             skills  \
# 0    ARTS  [Accounting, Policies, Training, Certification...
# 1    ARTS  [Training, Interactive, Teaching, Photography,...
# 2    ARTS  [Training, Data analysis, Instructional design...
# 3    ARTS                              [Teaching, Schedules]
# 4    ARTS  [Engineering, Illustrator, Administration, Mon...
# ..    ...                                                ...
# 98   ARTS  [Partnership, Training, Regulations, Technical...
# 99   ARTS  [Contracts, Inventory, Training, Regulations, ...
# 100  ARTS  [Administration, Inventory, Protocols, Invoice...
# 101  ARTS  [Twitter, Illustrator, Contracts, Training, Em...
# 102  ARTS  [Training, Health, Technical, Schedules, Sched...
#
#                                             experience
# 0    [03/2005 to Current, Arts Educator Company Nam...
# 1    [Arts Instructor , 08/1990 - 05/2012 Company N...
# 2    [English Language Arts Teacher 08/2009 to Curr...
# ...

# %%
# AUTOMOBILE


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/AUTOMOBILE')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/AUTOMOBILE'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/AUTOMOBILE/11797122.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/AUTOMOBILE/16332293.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/AUTOMOBILE/28790806.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/AUTOMOBILE/91515108.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/AUTOMOBILE/32109048.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/AUTOMOBILE/11152490.pdf
# ...

# %%
import pandas as pd
df6= pd.DataFrame(res_list)
df6['Label'] = "AUTOMOBILE"
df_label=df6['Label']
df_skills=df6['skills']
df_experience=df6['experience']
dataset6 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset6
# Out:
#          Label                                             skills  \
# 0   AUTOMOBILE  [Inventory, Compliance, Training, Regulatory, ...
# 1   AUTOMOBILE  [Requests, Inventory, Compliance, Training, Da...
# 2   AUTOMOBILE  [Training, Technical, Hive, Testing, Ibm, Work...
# 3   AUTOMOBILE  [Strategy, Call center, Travel, Process, Polic...
# 4   AUTOMOBILE  [Iso, Call center, Contracts, Compliance, Regu...
# 5   AUTOMOBILE  [Usability, Illustrator, Contracts, Administra...
# 6   AUTOMOBILE  [Contracts, Windows, Electrical, Technical, In...
# 7   AUTOMOBILE  [Call center, Administration, Training, Compli...
# 8   AUTOMOBILE  [Marketing plans, Usability, Contracts, Admini...
# 9   AUTOMOBILE  [Time management, Process, Contracts, Correspo...
# 10  AUTOMOBILE  [Engineering, Contracts, Administration, Compl...
# 11  AUTOMOBILE  [Time management, Training, Communication, Wor...
# 12  AUTOMOBILE  [Spreadsheets, Excel, Correspondence, Counsel,...
# ...

# %%
# AVIATION


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/AVIATION')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/AVIATION'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/AVIATION/69458502.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/AVIATION/82738323.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/AVIATION/16833515.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/AVIATION/11804712.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/AVIATION/21287405.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/AVIATION/10176815.pdf
# ...

# %%
import pandas as pd
df7= pd.DataFrame(res_list)
df7['Label'] = "AVIATION"
df_label=df7['Label']
df_skills=df7['skills']
df_experience=df7['experience']
dataset7 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset7
# Out:
#         Label                                             skills  \
# 0    AVIATION  [Engineering, Training, Compliance, Electrical...
# 1    AVIATION  [Aviation, Training, Electrical, Regulations, ...
# 2    AVIATION  [Inventory management, Time management, Ms exc...
# 3    AVIATION  [Compliance, Schematics, Electrical, Training,...
# 4    AVIATION  [Inventory, Training, Invoices, Regulatory, Te...
# ..        ...                                                ...
# 112  AVIATION  [Aviation, Engineering, Transport, Inventory, ...
# 113  AVIATION  [Engineering, Partnership, Real estate, Traini...
# 114  AVIATION  [Aviation, Inventory management, Inventory, Tr...
# 115  AVIATION  [Twitter, Operating systems, Training, Windows...
# 116  AVIATION  [Autocad, Inventory, Training, Peoplesoft, Adm...
#
#                                             experience
# 0    [Company Name City Aviation Engineer 01/2015 t...
# 1    [Company Name City , State Aviation Mechanic 0...
# ...

# %%
# BANKING


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/BANKING')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/BANKING'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/BANKING/74552449.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/BANKING/79041971.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/BANKING/77156708.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/BANKING/24580361.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/BANKING/34953092.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/BANKING/19920687.pdf
# ...

# %%
import pandas as pd
df8= pd.DataFrame(res_list)
df8['Label'] = "BANKING"
df_label=df8['Label']
df_skills=df8['skills']
df_experience=df8['experience']
dataset8 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset8
# Out:
#        Label                                             skills  \
# 0    BANKING  [Illustrator, Inventory, Administration, Analy...
# 1    BANKING  [Banking, Inventory, Training, Sales, Recruiti...
# 2    BANKING  [Marketing plans, Marketing strategy, Money, A...
# 3    BANKING  [Time management, Compliance, Regulations, Com...
# 4    BANKING  [Python, Engineering, Risk management, Analyti...
# ..       ...                                                ...
# 110  BANKING  [Strategy, Travel, Communication, Scheduling, ...
# 111  BANKING  [Administration, Invoices, Peoplesoft, Audit, ...
# 112  BANKING  [Partnership, Administration, Compliance, Trai...
# 113  BANKING  [Partnership, Real estate, Training, Hardware,...
# 114  BANKING  [Administration, Compliance, Audit, Brand, Tra...
#
#                                             experience
# 0    [Company Name City , State Banking 11/2016, Op...
# 1    [Banking, August 2013 to Current Company Name,...
# ...

# %%
# BPO


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/BPO')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/BPO'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/BPO/79261033.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/BPO/16492045.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/BPO/23933031.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/BPO/18589927.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/BPO/13964744.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/BPO/89512321.pdf
# ...

# %%
import pandas as pd
df9= pd.DataFrame(res_list)
df9['Label'] = "BPO"
df_label=df9['Label']
df_skills=df9['skills']
df_experience=df9['experience']
dataset9 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset9
# Out:
#    Label                                             skills  \
# 0    BPO  [Training, Engagement, Metrics, Spanish, Analy...
# 1    BPO  [Time management, Microsoft office suite, Admi...
# 2    BPO  [Kpis, Compliance, Training, Account managemen...
# 3    BPO  [Risk management, Inventory, Invoices, Regulat...
# 4    BPO  [Administration, Training, Windows, Technical,...
# 5    BPO  [Training, Compliance, Windows, Employee relat...
# 6    BPO  [Time management, Contracts, Inventory, Real e...
# 7    BPO  [Inventory, Administration, Training, Invoices...
# 8    BPO  [Administration, Training, Css, Protocols, Win...
# 9    BPO  [Training, Protocols, Windows, Analytical, Har...
# 10   BPO  [Engineering, Contracts, Training, Technical, ...
# 11   BPO  [Engineering, Illustrator, Training, Complianc...
# 12   BPO  [Peoplesoft, Brand, Technical, Coaching, Staff...
# 13   BPO  [Call center, Kpis, Risk management, Administr...
# 14   BPO  [Itil, Inventory, Training, Intranet, Windows,...
# ...

# %%
# BUSINESS-DEVELOPMENT


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/BUSINESS-DEVELOPMENT')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/BUSINESS-DEVELOPMENT'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/BUSINESS-DEVELOPMENT/65708020.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/BUSINESS-DEVELOPMENT/36805025.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/BUSINESS-DEVELOPMENT/13080868.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/BUSINESS-DEVELOPMENT/20748929.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/BUSINESS-DEVELOPMENT/38688388.pdf
# ...

# %%
import pandas as pd
df10= pd.DataFrame(res_list)
df10['Label'] = "BUSINESS-DEVELOPMENT"
df_label=df10['Label']
df_skills=df10['skills']
df_experience=df10['experience']
dataset10 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset10
# Out:
#                     Label                                             skills  \
# 0    BUSINESS-DEVELOPMENT  [Contracts, Inventory, Training, Compliance, A...
# 1    BUSINESS-DEVELOPMENT  [Itil, Engineering, Call center, Contracts, Co...
# 2    BUSINESS-DEVELOPMENT  [Illustrator, Inventory, Training, Regulations...
# 3    BUSINESS-DEVELOPMENT  [Training, Engagement, Technical, Brand, Negot...
# 4    BUSINESS-DEVELOPMENT  [Inventory management, Contracts, Inventory, C...
# ..                    ...                                                ...
# 115  BUSINESS-DEVELOPMENT  [Statistical analysis, Presentations, Analyze,...
# 116  BUSINESS-DEVELOPMENT  [Inventory, Training, Brand, Technical, Prospe...
# 117  BUSINESS-DEVELOPMENT  [Contracts, Inventory, Analytical, Communicati...
# 118  BUSINESS-DEVELOPMENT  [Gis, Protocols, Analytical, Email, Regulation...
# 119  BUSINESS-DEVELOPMENT  [Analytical skills, Partnership, Analytical, N...
#
# ...

# %%
# CHEF


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/CHEF')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/CHEF'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/CHEF/15180322.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/CHEF/24221960.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/CHEF/24673903.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/CHEF/19007667.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/CHEF/30311202.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/CHEF/11121498.pdf
# ...

# %%
import pandas as pd
df11= pd.DataFrame(res_list)
df11['Label'] = "CHEF"
df_label=df11['Label']
df_skills=df11['skills']
df_experience=df11['experience']
dataset11 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset11
# Out:
#     Label                                             skills  \
# 0    CHEF  [Safety, International, Customer service, Heal...
# 1    CHEF  [Safety, Process, System, Windows, Regulations...
# 2    CHEF  [Inventory, Customer service, Transactions, Sa...
# 3    CHEF  [Inventory, Ordering, Scheduling, Logistics, E...
# 4    CHEF  [Inventory, Training, Teaching, Communication,...
# ..    ...                                                ...
# 113  CHEF  [Time management, Microsoft office suite, Cont...
# 114  CHEF  [Inventory, Training, Communication, Supervisi...
# 115  CHEF  [Inventory, Training, Compliance, Administrati...
# 116  CHEF  [Administration, Training, Staffing, Communica...
# 117  CHEF  [Safety, Requests, Inventory, Compliance, Trai...
#
#                                             experience
# 0    [Positioned residents for comfort and to preve...
# 1     [customer service based., Daily cleaning duties]
# 2    [golf/tennis/pool facility., Was continuously ...
# ...

# %%
# CONSTRUCTION


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/CONSTRUCTION')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/CONSTRUCTION'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)


import pandas as pd
df12= pd.DataFrame(res_list)
df12['Label'] = "CONSTRUCTION"
df_label=df12['Label']
df_skills=df12['skills']
df_experience=df12['experience']
dataset12 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset12
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/CONSTRUCTION/10734870.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/CONSTRUCTION/99433371.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/CONSTRUCTION/18472240.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/CONSTRUCTION/29087505.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/CONSTRUCTION/71576860.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/CONSTRUCTION/33141415.pdf
# ...

# %%
# CONSULTANT


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/CONSULTANT')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/CONSULTANT'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)


import pandas as pd
df13= pd.DataFrame(res_list)
df13['Label'] = "CONSULTANT"
df_label=df13['Label']
df_skills=df13['skills']
df_experience=df13['experience']
dataset13 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset13
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/CONSULTANT/27096471.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/CONSULTANT/43311839.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/CONSULTANT/88907739.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/CONSULTANT/15119529.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/CONSULTANT/31395742.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/CONSULTANT/25694422.pdf
# ...

# %%
# DESIGNER


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/DESIGNER')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/DESIGNER'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)


import pandas as pd
df14= pd.DataFrame(res_list)
df14['Label'] = "DESIGNER"
df_label=df14['Label']
df_skills=df14['skills']
df_experience=df14['experience']
dataset14 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset14
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/DESIGNER/37058472.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/DESIGNER/68240723.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/DESIGNER/76010167.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/DESIGNER/19164410.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/DESIGNER/29147100.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/DESIGNER/25061645.pdf
# ...

# %%
# DIGITAL-MEDIA


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/DIGITAL-MEDIA')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/DIGITAL-MEDIA'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)


import pandas as pd
df15= pd.DataFrame(res_list)
df15['Label'] = "DIGITAL-MEDIA"
df_label=df15['Label']
df_skills=df15['skills']
df_experience=df15['experience']
dataset15 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset15
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/DIGITAL-MEDIA/13837784.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/DIGITAL-MEDIA/16509761.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/DIGITAL-MEDIA/29915354.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/DIGITAL-MEDIA/82929064.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/DIGITAL-MEDIA/14945250.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/DIGITAL-MEDIA/10515955.pdf
# ...

# %%
# ENGINEERING


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/ENGINEERING')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/ENGINEERING'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)


import pandas as pd
df16= pd.DataFrame(res_list)
df16['Label'] = "ENGINEERING"
df_label=df16['Label']
df_skills=df16['skills']
df_experience=df16['experience']
dataset16 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset16
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/ENGINEERING/14206561.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/ENGINEERING/15139979.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/ENGINEERING/44624796.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/ENGINEERING/54227873.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/ENGINEERING/28005884.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/ENGINEERING/82246962.pdf
# ...

# %%
# FINANCE


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/FINANCE')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/FINANCE'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)


import pandas as pd
df17= pd.DataFrame(res_list)
df17['Label'] = "FINANCE"
df_label=df17['Label']
df_skills=df17['skills']
df_experience=df17['experience']
dataset17 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset17
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/FINANCE/86549455.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/FINANCE/11877150.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/FINANCE/23955183.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/FINANCE/26530575.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/FINANCE/24854026.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/FINANCE/14722634.pdf
# ...

# %%
# FITNESS


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/FITNESS')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/FITNESS'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)


import pandas as pd
df18= pd.DataFrame(res_list)
df18['Label'] = "FITNESS"
df_label=df18['Label']
df_skills=df18['skills']
df_experience=df18['experience']
dataset18 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset18
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/FITNESS/17576030.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/FITNESS/24444525.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/FITNESS/10268614.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/FITNESS/29792535.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/FITNESS/15932017.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/FITNESS/23063986.pdf
# ...

# %%
# HEALTHCARE


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/HEALTHCARE')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/HEALTHCARE'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)


import pandas as pd
df19= pd.DataFrame(res_list)
df19['Label'] = "HEALTHCARE"
df_label=df19['Label']
df_skills=df19['skills']
df_experience=df19['experience']
dataset19 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset19
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/HEALTHCARE/23617240.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/HEALTHCARE/23138078.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/HEALTHCARE/69199666.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/HEALTHCARE/51777546.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/HEALTHCARE/93988900.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/HEALTHCARE/41910253.pdf
# ...

# %%
# HR


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/HR')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/HR'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)


import pandas as pd
df20= pd.DataFrame(res_list)
df20['Label'] = "HR"
df_label=df20['Label']
df_skills=df20['skills']
df_experience=df20['experience']
dataset20 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset20
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/HR/22323967.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/HR/16852973.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/HR/33176873.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/HR/17812897.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/HR/27018550.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/HR/11592605.pdf
# ...

# %%
# INFORMATION-TECHNOLOGY


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/INFORMATION-TECHNOLOGY')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/INFORMATION-TECHNOLOGY'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)


import pandas as pd
df21= pd.DataFrame(res_list)
df21['Label'] = "INFORMATION-TECHNOLOGY"
df_label=df21['Label']
df_skills=df21['skills']
df_experience=df21['experience']
dataset21 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset21
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/INFORMATION-TECHNOLOGY/36856210.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/INFORMATION-TECHNOLOGY/21780877.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/INFORMATION-TECHNOLOGY/33241454.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/INFORMATION-TECHNOLOGY/25990239.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/INFORMATION-TECHNOLOGY/16899268.pdf
# ...

# %%
# PUBLIC-RELATIONS


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/PUBLIC-RELATIONS')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/PUBLIC-RELATIONS'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)


import pandas as pd
df22= pd.DataFrame(res_list)
df22['Label'] = "PUBLIC-RELATIONS"
df_label=df22['Label']
df_skills=df22['skills']
df_experience=df22['experience']
dataset22 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset22
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/PUBLIC-RELATIONS/31392754.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/PUBLIC-RELATIONS/23143731.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/PUBLIC-RELATIONS/25070914.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/PUBLIC-RELATIONS/26130673.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/PUBLIC-RELATIONS/37913536.pdf
# ...

# %%
# SALES


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/SALES')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/SALES'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)


import pandas as pd
df23= pd.DataFrame(res_list)
df23['Label'] = "SALES"
df_label=df23['Label']
df_skills=df23['skills']
df_experience=df23['experience']
dataset23 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset23
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/SALES/87118391.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/SALES/27607632.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/SALES/33578873.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/SALES/23760084.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/SALES/30083943.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/SALES/20552814.pdf
# ...

# %%
# TEACHER


dir_list = os.listdir(r'/content/drive/MyDrive/CV Sorting Project/data/TEACHER')
#print(dir_list)

res_list = []

paths = r'/content/drive/MyDrive/CV Sorting Project/data/TEACHER'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    print("pfinal",c,"---->",pfinal)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)


import pandas as pd
df24= pd.DataFrame(res_list)
df24['Label'] = "TEACHER"
df_label=df24['Label']
df_skills=df24['skills']
df_experience=df24['experience']
dataset24 = pd.concat([df_label, df_skills,df_experience], join = 'outer', axis = 1)
dataset24
# Out:
# pfinal 1 ----> /content/drive/MyDrive/CV Sorting Project/data/TEACHER/12467531.pdf
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# pfinal 2 ----> /content/drive/MyDrive/CV Sorting Project/data/TEACHER/62184086.pdf
# pfinal 3 ----> /content/drive/MyDrive/CV Sorting Project/data/TEACHER/19918523.pdf
# pfinal 4 ----> /content/drive/MyDrive/CV Sorting Project/data/TEACHER/28063132.pdf
# pfinal 5 ----> /content/drive/MyDrive/CV Sorting Project/data/TEACHER/22408666.pdf
# pfinal 6 ----> /content/drive/MyDrive/CV Sorting Project/data/TEACHER/29797594.pdf
# ...

# %%
dataset1
# Out:
#           Label                                             skills  \
# 0    ACCOUNTANT  [Partnership, Compliance, Protocols, Invoices,...
# 1    ACCOUNTANT  [Process, Certification, Vendors, Tax, Analysi...
# 2    ACCOUNTANT  [Contracts, Inventory, Compliance, Peoplesoft,...
# 3    ACCOUNTANT  [Compliance, Invoices, Analytical, Regulations...
# 4    ACCOUNTANT  [Illustrator, Contracts, Inventory, Invoices, ...
# ..          ...                                                ...
# 113  ACCOUNTANT  [Transactions, Communication, Mobile, Workflow...
# 114  ACCOUNTANT  [Cash flow, Compliance, Invoices, Analytical, ...
# 115  ACCOUNTANT  [Cash flow, Inventory, Invoices, Audit, Financ...
# 116  ACCOUNTANT  [Contracts, Administration, Real estate, Invoi...
# 117  ACCOUNTANT  [Compliance, Invoices, Process improvements, I...
#
#                                             experience
# 0    [Services, Financial statements, Bank reconcil...
# ...

# %%
dataset2
# Out:
#         Label                                             skills  \
# 0    ADVOCATE  [Public policy, Partnership, German, Training,...
# 1    ADVOCATE  [Partnership, Administration, Training, Money,...
# 2    ADVOCATE  [Administration, Training, Technical, Coaching...
# 3    ADVOCATE  [Strategy, Safety, Math, Travel, Communication...
# 5    ADVOCATE    [System, Money, Staffing, Sales, Recruit, Plan]
# ..        ...                                                ...
# 112  ADVOCATE  [Administration, Training, Inventory, Supervis...
# 113  ADVOCATE  [Strategy, Correspondence, Policies, Training,...
# 115  ADVOCATE  [International, Excel, Presentations, Complian...
# 116  ADVOCATE  [Swot analysis, Training, Compliance, Program ...
# 117  ADVOCATE  [Training, Coaching, Phone calls, Powerpoint, ...
#
#                                             experience
# 0    [Advocate , 01/2011 to 01/2013 Company Name ï¼...
# 1    [Handle client email/phone call interactions o...
# ...

# %%
dataset3
# Out:
#           Label                                             skills  \
# 0   AGRICULTURE  [Training, Technical, Communication, Safety, G...
# 1   AGRICULTURE  [Inventory, Training, Invoices, Analytical, Pu...
# 2   AGRICULTURE  [Cash flow, Training, Engagement, Technical, H...
# 3   AGRICULTURE  [Illustrator, Compliance, Peoplesoft, Regulati...
# 4   AGRICULTURE  [Administration, Training, Compliance, Invento...
# ..          ...                                                ...
# 58  AGRICULTURE  [Iso, Administration, Training, Protocols, Reg...
# 59  AGRICULTURE  [Administration, Training, Analytical, Communi...
# 60  AGRICULTURE  [Administration, Training, Compliance, Negotia...
# 61  AGRICULTURE  [Twitter, Inventory, Training, Chemicals, Mone...
# 62  AGRICULTURE  [Gis, Training, Technical, Communication, Spor...
#
#                                            experience
# 0   [Jan 2016 to Jan 2016, work as Language office...
# ...

# %%
dataset4
# Out:
#       Label                                             skills  \
# 0   APPAREL  [Administration, Training, Sales, Recruiting, ...
# 1   APPAREL  [Contracts, Inventory, Compliance, Training, S...
# 2   APPAREL  [Fabric, Inventory, Compliance, Invoices, Admi...
# 3   APPAREL  [Illustrator, Partnership, Technical, Teaching...
# 4   APPAREL  [Partnership, Inventory, Training, Brand, Coac...
# ..      ...                                                ...
# 92  APPAREL  [Microsoft office suite, Administration, Inven...
# 93  APPAREL  [Marketing plans, Brand, Alliances, Partnershi...
# 94  APPAREL  [Excel, Training, Certification, Customer serv...
# 95  APPAREL  [Real estate, Compliance, Windows, Regulations...
# 96  APPAREL  [Partnership, Contracts, Training, Compliance,...
#
#                                            experience
# 0   [Apparel Associate Aug 2017 to Current, Compan...
# 1   [10/2017 to 12/2017, Apparel Sales Associate/C...
# ...

# %%
dataset5
# Out:
#     Label                                             skills  \
# 0    ARTS  [Accounting, Policies, Training, Certification...
# 1    ARTS  [Training, Interactive, Teaching, Photography,...
# 2    ARTS  [Training, Data analysis, Instructional design...
# 3    ARTS                              [Teaching, Schedules]
# 4    ARTS  [Engineering, Illustrator, Administration, Mon...
# ..    ...                                                ...
# 98   ARTS  [Partnership, Training, Regulations, Technical...
# 99   ARTS  [Contracts, Inventory, Training, Regulations, ...
# 100  ARTS  [Administration, Inventory, Protocols, Invoice...
# 101  ARTS  [Twitter, Illustrator, Contracts, Training, Em...
# 102  ARTS  [Training, Health, Technical, Schedules, Sched...
#
#                                             experience
# 0    [03/2005 to Current, Arts Educator Company Nam...
# 1    [Arts Instructor , 08/1990 - 05/2012 Company N...
# 2    [English Language Arts Teacher 08/2009 to Curr...
# ...

# %%
dataset6
# Out:
#          Label                                             skills  \
# 0   AUTOMOBILE  [Inventory, Compliance, Training, Regulatory, ...
# 1   AUTOMOBILE  [Requests, Inventory, Compliance, Training, Da...
# 2   AUTOMOBILE  [Training, Technical, Hive, Testing, Ibm, Work...
# 3   AUTOMOBILE  [Strategy, Call center, Travel, Process, Polic...
# 4   AUTOMOBILE  [Iso, Call center, Contracts, Compliance, Regu...
# 5   AUTOMOBILE  [Usability, Illustrator, Contracts, Administra...
# 6   AUTOMOBILE  [Contracts, Windows, Electrical, Technical, In...
# 7   AUTOMOBILE  [Call center, Administration, Training, Compli...
# 8   AUTOMOBILE  [Marketing plans, Usability, Contracts, Admini...
# 9   AUTOMOBILE  [Time management, Process, Contracts, Correspo...
# 10  AUTOMOBILE  [Engineering, Contracts, Administration, Compl...
# 11  AUTOMOBILE  [Time management, Training, Communication, Wor...
# 12  AUTOMOBILE  [Spreadsheets, Excel, Correspondence, Counsel,...
# ...

# %%
dataset7
# Out:
#         Label                                             skills  \
# 0    AVIATION  [Engineering, Training, Compliance, Electrical...
# 1    AVIATION  [Aviation, Training, Electrical, Regulations, ...
# 2    AVIATION  [Inventory management, Time management, Ms exc...
# 3    AVIATION  [Compliance, Schematics, Electrical, Training,...
# 4    AVIATION  [Inventory, Training, Invoices, Regulatory, Te...
# ..        ...                                                ...
# 112  AVIATION  [Aviation, Engineering, Transport, Inventory, ...
# 113  AVIATION  [Engineering, Partnership, Real estate, Traini...
# 114  AVIATION  [Aviation, Inventory management, Inventory, Tr...
# 115  AVIATION  [Twitter, Operating systems, Training, Windows...
# 116  AVIATION  [Autocad, Inventory, Training, Peoplesoft, Adm...
#
#                                             experience
# 0    [Company Name City Aviation Engineer 01/2015 t...
# 1    [Company Name City , State Aviation Mechanic 0...
# ...

# %%
dataset8
# Out:
#        Label                                             skills  \
# 0    BANKING  [Illustrator, Inventory, Administration, Analy...
# 1    BANKING  [Banking, Inventory, Training, Sales, Recruiti...
# 2    BANKING  [Marketing plans, Marketing strategy, Money, A...
# 3    BANKING  [Time management, Compliance, Regulations, Com...
# 4    BANKING  [Python, Engineering, Risk management, Analyti...
# ..       ...                                                ...
# 110  BANKING  [Strategy, Travel, Communication, Scheduling, ...
# 111  BANKING  [Administration, Invoices, Peoplesoft, Audit, ...
# 112  BANKING  [Partnership, Administration, Compliance, Trai...
# 113  BANKING  [Partnership, Real estate, Training, Hardware,...
# 114  BANKING  [Administration, Compliance, Audit, Brand, Tra...
#
#                                             experience
# 0    [Company Name City , State Banking 11/2016, Op...
# 1    [Banking, August 2013 to Current Company Name,...
# ...

# %%
dataset9
# Out:
#    Label                                             skills  \
# 0    BPO  [Training, Engagement, Metrics, Spanish, Analy...
# 1    BPO  [Time management, Microsoft office suite, Admi...
# 2    BPO  [Kpis, Compliance, Training, Account managemen...
# 3    BPO  [Risk management, Inventory, Invoices, Regulat...
# 4    BPO  [Administration, Training, Windows, Technical,...
# 5    BPO  [Training, Compliance, Windows, Employee relat...
# 6    BPO  [Time management, Contracts, Inventory, Real e...
# 7    BPO  [Inventory, Administration, Training, Invoices...
# 8    BPO  [Administration, Training, Css, Protocols, Win...
# 9    BPO  [Training, Protocols, Windows, Analytical, Har...
# 10   BPO  [Engineering, Contracts, Training, Technical, ...
# 11   BPO  [Engineering, Illustrator, Training, Complianc...
# 12   BPO  [Peoplesoft, Brand, Technical, Coaching, Staff...
# 13   BPO  [Call center, Kpis, Risk management, Administr...
# 14   BPO  [Itil, Inventory, Training, Intranet, Windows,...
# ...

# %%
dataset10
# Out:
#                     Label                                             skills  \
# 0    BUSINESS-DEVELOPMENT  [Contracts, Inventory, Training, Compliance, A...
# 1    BUSINESS-DEVELOPMENT  [Itil, Engineering, Call center, Contracts, Co...
# 2    BUSINESS-DEVELOPMENT  [Illustrator, Inventory, Training, Regulations...
# 3    BUSINESS-DEVELOPMENT  [Training, Engagement, Technical, Brand, Negot...
# 4    BUSINESS-DEVELOPMENT  [Inventory management, Contracts, Inventory, C...
# ..                    ...                                                ...
# 115  BUSINESS-DEVELOPMENT  [Statistical analysis, Presentations, Analyze,...
# 116  BUSINESS-DEVELOPMENT  [Inventory, Training, Brand, Technical, Prospe...
# 117  BUSINESS-DEVELOPMENT  [Contracts, Inventory, Analytical, Communicati...
# 118  BUSINESS-DEVELOPMENT  [Gis, Protocols, Analytical, Email, Regulation...
# 119  BUSINESS-DEVELOPMENT  [Analytical skills, Partnership, Analytical, N...
#
# ...

# %%
dataset11
# Out:
#     Label                                             skills  \
# 0    CHEF  [Safety, International, Customer service, Heal...
# 1    CHEF  [Safety, Process, System, Windows, Regulations...
# 2    CHEF  [Inventory, Customer service, Transactions, Sa...
# 3    CHEF  [Inventory, Ordering, Scheduling, Logistics, E...
# 4    CHEF  [Inventory, Training, Teaching, Communication,...
# ..    ...                                                ...
# 113  CHEF  [Time management, Microsoft office suite, Cont...
# 114  CHEF  [Inventory, Training, Communication, Supervisi...
# 115  CHEF  [Inventory, Training, Compliance, Administrati...
# 116  CHEF  [Administration, Training, Staffing, Communica...
# 117  CHEF  [Safety, Requests, Inventory, Compliance, Trai...
#
#                                             experience
# 0    [Positioned residents for comfort and to preve...
# 1     [customer service based., Daily cleaning duties]
# 2    [golf/tennis/pool facility., Was continuously ...
# ...

# %%
dataset12
# Out:
#             Label                                             skills  \
# 0    CONSTRUCTION  [Inventory, Training, Schematics, Chemicals, C...
# 1    CONSTRUCTION  [Illustrator, Autocad, Excel, Payroll, Adminis...
# 2    CONSTRUCTION  [Inventory, Windows, Vendors, C, Construction,...
# 3    CONSTRUCTION  [Training, Windows, Analytical, Wordpress, Eng...
# 4    CONSTRUCTION  [Inventory, Training, Compliance, Money, Commu...
# ..            ...                                                ...
# 107  CONSTRUCTION  [Customer service, Money, Transactions, Word, ...
# 108  CONSTRUCTION  [Ms excel, Autocad, Contracts, Inventory, Invo...
# 109  CONSTRUCTION  [Safety, Inventory, Cement, Chemicals, Health,...
# 110  CONSTRUCTION  [Safety, Policies, Compliance, Windows, Regula...
# 111  CONSTRUCTION  [Engineering, Compliance, Analytical, Regulati...
#
#                                             experience
# 0    [01/2014 to 01/2015, Construction Company Name...
# ...

# %%
dataset13
# Out:
#           Label                                             skills  \
# 0    CONSULTANT  [Iso, Risk management, Administration, Complia...
# 1    CONSULTANT  [Engineering, Operating systems, Ui, Css, Wind...
# 2    CONSULTANT  [Engineering, Usability, Microsoft office suit...
# 3    CONSULTANT  [Brand, Technical, Mock, E-commerce, Saas, Sta...
# 4    CONSULTANT  [Usability, Administration, Training, Inventor...
# ..          ...                                                ...
# 110  CONSULTANT  [Time management, Engineering, Kpis, Administr...
# 111  CONSULTANT  [Risk management, Contracts, Administration, C...
# 112  CONSULTANT  [Contracts, Training, Analytical, Email, Negot...
# 113  CONSULTANT  [Training, Windows, Phone calls, Sales, Photos...
# 114  CONSULTANT  [Financial performance, Analytical, Ux, Metric...
#
#                                             experience
# 0    [Participated in the development of the employ...
# ...

# %%
dataset14
# Out:
#         Label                                             skills  \
# 0    DESIGNER  [Engineering, Autocad, Inventory, Compliance, ...
# 1    DESIGNER  [Time management, Illustrator, Fabric, Brand, ...
# 2    DESIGNER  [Math, Time management, Excel, Biology, Econom...
# 3    DESIGNER  [Illustrator, Fabric, Administration, Invoices...
# 4    DESIGNER  [Illustrator, Presentations, Indesign, Brandin...
# ..        ...                                                ...
# 102  DESIGNER  [Presentations, Orange, Accounting, Training, ...
# 103  DESIGNER  [Microsoft office suite, Css, Brand, Mock, Mob...
# 104  DESIGNER  [Safety, Engineering, Cad, Autocad, Merchant, ...
# 105  DESIGNER  [Illustrator, Presentations, Photography, Adob...
# 106  DESIGNER  [Administration, Training, Electrical, Technic...
#
#                                             experience
# 0    [03/2014 to 11/2015, Designer Company Name - C...
# 1    [DESIGNER 10/2013 to 06/2015 Company Name City...
# ...

# %%
dataset15
# Out:
#             Label                                             skills  \
# 0   DIGITAL-MEDIA  [Twitter, Money, Wordpress, Brand, Account man...
# 1   DIGITAL-MEDIA  [Administration, Training, Construction, Spani...
# 2   DIGITAL-MEDIA  [Illustrator, Training, Editing, Teaching, Com...
# 3   DIGITAL-MEDIA  [Account management, Hardware, Metrics, Spanis...
# 4   DIGITAL-MEDIA  [Training, Windows, Email, Brand, Negotiation,...
# ..            ...                                                ...
# 91  DIGITAL-MEDIA  [Inventory, Training, Ui, Css, Negotiation, Br...
# 92  DIGITAL-MEDIA  [Twitter, Illustrator, Administration, Complia...
# 93  DIGITAL-MEDIA  [Marketing strategy, Training, Affiliate, Anal...
# 94  DIGITAL-MEDIA  [Engineering, Illustrator, Training, Css, Emai...
# 95  DIGITAL-MEDIA  [Twitter, Illustrator, Marketing strategy, Ana...
#
#                                            experience
# 0   [Company Name City , State Digital Media Buyer...
# ...

# %%
dataset16
# Out:
#            Label                                             skills  \
# 0    ENGINEERING  [Ms excel, Engineering, Administration, Traini...
# 1    ENGINEERING  [Engineering, Administration, Training, Compli...
# 2    ENGINEERING  [Engineering, Compliance, Training, Windows, A...
# 3    ENGINEERING  [Ms excel, Engineering, Autocad, Python, Windo...
# 4    ENGINEERING  [Engineering, Autocad, Compliance, System, Dra...
# ..           ...                                                ...
# 113  ENGINEERING  [Engineering, Autocad, Iso, Statistical analys...
# 114  ENGINEERING  [Engineering, Compliance, Regulatory, Technica...
# 115  ENGINEERING  [Engineering, Autocad, Training, Schematics, A...
# 116  ENGINEERING  [Engineering, Administration, Training, Schema...
# 117  ENGINEERING  [Engineering, Mechanical engineering, Research...
#
#                                             experience
# 0    [Company Name City , State Engineering Technic...
# ...

# %%
dataset17
# Out:
#        Label                                             skills  \
# 0    FINANCE  [Contracts, Training, Scheduling, Leadership d...
# 1    FINANCE  [Analytical, Transactions, Financial reports, ...
# 2    FINANCE  [Administration, Compliance, Training, Analyti...
# 3    FINANCE  [Engineering, Risk management, Administration,...
# 4    FINANCE  [Administration, Compliance, Vendor management...
# ..       ...                                                ...
# 113  FINANCE  [Engineering, Inventory, Compliance, Analytica...
# 114  FINANCE  [Administration, Training, Compliance, Regulat...
# 115  FINANCE  [Risk management, Contracts, Compliance, Train...
# 116  FINANCE  [Financial performance, Iso, Inventory, Admini...
# 117  FINANCE  [Inventory, Training, Invoices, Compliance, Re...
#
#                                             experience
# 0    [Finance, July 2008 to October 2015 Company Na...
# 1                                                 None
# ...

# %%
dataset18
# Out:
#        Label                                             skills  \
# 0    FITNESS  [Fitness, Content, Training, Sales, Cpr, Marke...
# 1    FITNESS  [Excel, Fitness, Training, Certification, Sche...
# 2    FITNESS  [Engineering, Annual budget, Training, Communi...
# 3    FITNESS  [Illustrator, Administration, Training, Invent...
# 4    FITNESS  [Fitness, Financing, Training, Certification, ...
# ..       ...                                                ...
# 112  FITNESS  [Training, Health, Hospitality, Sales, Communi...
# 113  FITNESS  [Twitter, Call center, Microsoft office suite,...
# 114  FITNESS  [Engineering, Iso, Training, Chemicals, Analyt...
# 115  FITNESS  [Contracts, Inventory, Training, Compliance, A...
# 116  FITNESS  [Training, Email, Staffing, Communication, Mic...
#
#                                             experience
# 0    [09/2013 to 03/2014, Fitness Consultant Compan...
# 1    [Monitored the academic performance of student...
# ...

# %%
dataset19
# Out:
#           Label                                             skills  \
# 0    HEALTHCARE  [Call center, Risk management, Contracts, Real...
# 1    HEALTHCARE  [Time management, Contracts, Administration, T...
# 2    HEALTHCARE  [Inventory, Training, Coaching, Staffing, Metr...
# 3    HEALTHCARE  [Microsoft office suite, Contracts, Inventory,...
# 4    HEALTHCARE  [Partnership, Administration, Training, Compli...
# ..          ...                                                ...
# 110  HEALTHCARE  [Inventory, Training, Money, Transactions, Sta...
# 111  HEALTHCARE  [Healthcare, Therapeutic, Communication, Polic...
# 112  HEALTHCARE  [Marketing plans, Training, Compliance, Regula...
# 113  HEALTHCARE  [Peoplesoft, French, Powerpoint, Safety, Payro...
# 114  HEALTHCARE  [Safety, Travel, Process, Policies, Training, ...
#
#                                             experience
# 0    [Healthcare, May 2001 Company Name ï¼​ City , ...
# ...

# %%
dataset20
# Out:
#     Label                                             skills  \
# 0      HR  [Illustrator, Inventory, Training, Brand, Metr...
# 1      HR  [Time management, Analytical skills, Inventory...
# 2      HR  [Administration, Compliance, Training, Regulat...
# 3      HR  [Contracts, Administration, Training, Complian...
# 4      HR  [Administration, Training, Email, Transactions...
# ..    ...                                                ...
# 105    HR  [Ms excel, Iso, Contracts, Administration, Tra...
# 106    HR  [Administration, Training, Peoplesoft, Complia...
# 107    HR  [Cash flow, Administration, Regulations, Emplo...
# 108    HR  [Administration, Compliance, Training, Regulat...
# 109    HR  [Time management, Inventory, Compliance, Train...
#
#                                             experience
# 0    [09/2015 to Current, HR Specialist, US HR Oper...
# 1    [HR Administrator/Marketing Associate HR Admin...
# 2    [HR Director 09/2016 to Current Company Name C...
# ...

# %%
dataset21
# Out:
#                       Label  \
# 0    INFORMATION-TECHNOLOGY
# 1    INFORMATION-TECHNOLOGY
# 2    INFORMATION-TECHNOLOGY
# 3    INFORMATION-TECHNOLOGY
# 4    INFORMATION-TECHNOLOGY
# ..                      ...
# 115  INFORMATION-TECHNOLOGY
# 116  INFORMATION-TECHNOLOGY
# 117  INFORMATION-TECHNOLOGY
# 118  INFORMATION-TECHNOLOGY
# 119  INFORMATION-TECHNOLOGY
#
#                                                 skills  \
# 0    [Engineering, Illustrator, Compliance, Trainin...
# 1    [Engineering, Training, Electrical, Hardware, ...
# 2    [Inventory, Training, Protocols, Windows, Tech...
# 3    [Illustrator, Inventory, Training, Windows, Ha...
# 4    [Intranet, Training, Email, Technical, Communi...
# ..                                                 ...
# 115  [Itil, Administration, Training, Compliance, W...
# 116  [Microsoft office suite, Contracts, Administra...
# 117  [Python, Inventory, Training, Windows, Email, ...
# 118  [Ms excel, Autocad, Real estate, Inventory, Tr...
# ...

# %%
dataset22
# Out:
#                 Label                                             skills  \
# 0    PUBLIC-RELATIONS  [Partnership, Training, Compliance, Staffing, ...
# 1    PUBLIC-RELATIONS  [International, Social media, Real estate, Cus...
# 2    PUBLIC-RELATIONS  [Marketing plans, Public relations, Sports, Ph...
# 3    PUBLIC-RELATIONS  [Policies, Training, Pr, Analysis, Sales, Secu...
# 4    PUBLIC-RELATIONS  [Twitter, Inventory, Training, Editing, Public...
# ..                ...                                                ...
# 106  PUBLIC-RELATIONS  [Twitter, Analytical, Email, Brand, Engagement...
# 107  PUBLIC-RELATIONS  [Training, Affiliate, Internal customers, Anal...
# 108  PUBLIC-RELATIONS  [Twitter, Illustrator, Partnership, Inventory,...
# 109  PUBLIC-RELATIONS  [Twitter, Administration, Brand, Metrics, Comm...
# 110  PUBLIC-RELATIONS  [Marketing plans, Training, Technical, Communi...
#
#                                             experience
# ...

# %%
dataset23
# Out:
#      Label                                             skills  \
# 0    SALES  [Training, Compliance, Regulations, Email, Tra...
# 1    SALES  [Time management, Inventory, Training, Invoice...
# 2    SALES  [Training, Mortgage, Sales, Security, Retail, ...
# 3    SALES  [Time management, Contracts, Inventory, Traini...
# 4    SALES  [Travel, Administration, Compliance, Certifica...
# ..     ...                                                ...
# 111  SALES  [Beverage, Excel, Process, Training, Customer ...
# 112  SALES  [Administration, Communication, Mining, Resear...
# 113  SALES  [Inventory, Policies, Responses, Technical, Tr...
# 114  SALES  [Safety, Call center, Payments, Travel, Proces...
# 115  SALES  [Compliance, Regulations, Invoicing, Communica...
#
#                                             experience
# 0    [Sales, September 2008 Company Name ï¼​ City ,...
# 1    [04/2016 to Current, Sales Company Name ï¼​ Ci...
# ...

# %%
dataset24
# Out:
#        Label                                             skills  \
# 0    TEACHER  [Contracts, Engagement, Drafting, Partnerships...
# 1    TEACHER  [Time management, Training, Instructional desi...
# 2    TEACHER  [Communication, Administration, Training, Syst...
# 3    TEACHER  [Training, System, Publishing, Analytical, Cus...
# 4    TEACHER  [Safety, Training, System, English, Coaching, ...
# ..       ...                                                ...
# 97   TEACHER  [Safety, Communication, Filing, Administration...
# 98   TEACHER  [Safety, Budgeting, Process, Partnership, Poli...
# 99   TEACHER  [Usability, Metrics, Teaching, Event planning,...
# 100  TEACHER  [Time management, Inventory, Training, Adminis...
# 101  TEACHER  [Engineering, Autocad, Gis, Training, Complian...
#
#                                             experience
# 0                                                 None
# 1    [Teacher, August 2004 to March 2014 Company Na...
# ...

# %%
dataset_list = [dataset1, dataset2, dataset3,dataset4,dataset5,dataset6,dataset7,dataset8,dataset9,dataset10,dataset11,dataset12,dataset13,dataset14,dataset15,dataset16,dataset17,dataset18,dataset19,dataset20,dataset21,dataset22,dataset23,dataset24]
len(dataset_list)
# Out:
# 24

# %%
final_dataset = pd.concat(dataset_list)

# %%
final_dataset
# Out:
#           Label                                             skills  \
# 0    ACCOUNTANT  [Partnership, Compliance, Protocols, Invoices,...
# 1    ACCOUNTANT  [Process, Certification, Vendors, Tax, Analysi...
# 2    ACCOUNTANT  [Contracts, Inventory, Compliance, Peoplesoft,...
# 3    ACCOUNTANT  [Compliance, Invoices, Analytical, Regulations...
# 4    ACCOUNTANT  [Illustrator, Contracts, Inventory, Invoices, ...
# ..          ...                                                ...
# 97      TEACHER  [Safety, Communication, Filing, Administration...
# 98      TEACHER  [Safety, Budgeting, Process, Partnership, Poli...
# 99      TEACHER  [Usability, Metrics, Teaching, Event planning,...
# 100     TEACHER  [Time management, Inventory, Training, Adminis...
# 101     TEACHER  [Engineering, Autocad, Gis, Training, Complian...
#
#                                             experience
# 0    [Services, Financial statements, Bank reconcil...
# ...

# %%
print(final_dataset.isnull().sum())
# Out:
# Label          0
# skills         0
# experience    84
# dtype: int64

# %%
final_dataset.dropna(inplace=True)

# %%
print(final_dataset.isnull().sum())
# Out:
# Label         0
# skills        0
# experience    0
# dtype: int64

# %%
final_dataset.shape
# Out:
# (2386, 3)

# %%
final_dataset.to_csv('resume_files.csv')
# !cp data.csv "drive/My Drive/"
# Out:
# cp: cannot stat 'data.csv': No such file or directory

# %%
resume=data["skills"]
skills=[]
skills.append(' '.join(word for word in resume))

# %%
skills[0]
# Out:
# 'Engineering Autocad Gis Training Compliance Electrical Analytical Windows Engagement Drafting Technical Css Wordpress Teaching Communication Lighting Mechanical engineering Mathematics Microsoft office Scheduling Analysis Schedules Supervisor Photoshop Design Reports Product knowledge Plan Programming Specifications Android Math Budgeting Presentations Retention Pharmaceutical Word Networking Solidworks Cad Adobe Excel Process System Certification Quality control Troubleshooting Html Access Construction Database'

# %%
pip install ftfy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import re

from ftfy import fix_text

def ngrams(string, n=3):
    string = fix_text(string) # fix text
    string = string.encode("ascii", errors="ignore").decode() #remove non ascii chars
    string = string.lower()
    chars_to_remove = [")","(",".","|","[","]","{","}","'"]
    rx = '[' + re.escape(''.join(chars_to_remove)) + ']'
    string = re.sub(rx, '', string)
    string = string.replace('&', 'and')
    string = string.replace(',', ' ')
    string = string.replace('-', ' ')
    string = string.title() # normalise case - capital at start of each word
    string = re.sub(' +',' ',string).strip() # get rid of multiple spaces and replace with a single
    string = ' '+ string +' ' # pad names for ngrams...
    string = re.sub(r'[,-./]|\sBD',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import re

# %%
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams, lowercase=False)
tfidf = vectorizer.fit_transform(skills)

# %%
tfidf
# Out:
# <1x377 sparse matrix of type '<class 'numpy.float64'>'
# 	with 377 stored elements in Compressed Sparse Row format>
